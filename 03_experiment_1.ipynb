# %%
import os

import pandas as pd
from time import time
from joblib import load, dump

# %%
from sklearn.model_selection import GridSearchCV, RepeatedStratifiedKFold, RepeatedKFold, train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.linear_model import SGDClassifier, SGDRegressor, Ridge, LogisticRegression
from xgboost import XGBClassifier, XGBRegressor
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, PolynomialFeatures
from sklearn.metrics import f1_score, accuracy_score, recall_score, precision_score, r2_score, mean_squared_error, mean_absolute_error

# %%
seed = 42

# %%
csv_path = os.path.join('data', 'fires_transformed.csv')
df = pd.read_csv(csv_path)
df.sample(5, random_state=seed)
# Out:
#           elevacion  erodi   slope  orientacion_sen  orientacion_cos  altura  \
# 119340  1024.904053      4  15.177         0.994650         0.103298     9.0
# 58023    505.352997      1  25.718         0.206331         0.978482     3.0
# 46997    388.710999      2  31.593        -0.984000         0.178167     1.0
# 67214   1063.177002      1  22.364         0.901304        -0.433188     2.0
# 153590   507.516998      3  13.911         0.872081         0.489362     3.0
#
#              lfcc  inflam  mcroth   anomalia       dpv  vel_media_viento  \
# 119340  46.956501       3       2  73.561211  2.246882          2.916394
# 58023   19.892401       4       3  86.961823  2.385298          4.876472
# 46997    0.956900       4       3  79.168137  2.319516          5.026659
# 67214    7.424201       4       1  50.321835  0.349119          2.470344
# 153590  32.275799       4       3  72.893860  1.469779          3.393716
#
#         severidad_real  severidad_discreta  coord_x_etrs89  coord_y_etrs89  \
# 119340        0.845614                   3        490110.0       4538190.0
# 58023         0.270908                   1        604950.0       4257480.0
# 46997         0.412787                   1        617730.0       4243860.0
# 67214         0.576249                   2        561090.0       4256790.0
# 153590        0.310006                   1        407340.0       4412550.0
#
#          incendio    provincia
# 119340  Cogolludo  Guadalajara
# 58023      Talave     Albacete
# 46997    Donceles     Albacete
# 67214       Yeste     Albacete
# 153590  Montesion       Toledo

# %%
numerical_variables = ['elevacion', 'slope', 'orientacion_sen', 'orientacion_cos', 'altura', 'lfcc', 'anomalia', 'dpv', 'vel_media_viento']
categorical_variables = ['erodi', 'inflam', 'mcroth']
variables = numerical_variables + categorical_variables
target_real = 'severidad_real'
target_discrete = 'severidad_discreta'

# %% [markdown]
# # Regresión

# %%
X = df[variables]
y = df[target_real]

# %%
X.sample(5, random_state=seed)
# Out:
#           elevacion   slope  orientacion_sen  orientacion_cos  altura  \
# 119340  1024.904053  15.177         0.994650         0.103298     9.0
# 58023    505.352997  25.718         0.206331         0.978482     3.0
# 46997    388.710999  31.593        -0.984000         0.178167     1.0
# 67214   1063.177002  22.364         0.901304        -0.433188     2.0
# 153590   507.516998  13.911         0.872081         0.489362     3.0
#
#              lfcc   anomalia       dpv  vel_media_viento  erodi  inflam  \
# 119340  46.956501  73.561211  2.246882          2.916394      4       3
# 58023   19.892401  86.961823  2.385298          4.876472      1       4
# 46997    0.956900  79.168137  2.319516          5.026659      2       4
# 67214    7.424201  50.321835  0.349119          2.470344      1       4
# 153590  32.275799  72.893860  1.469779          3.393716      3       4
#
#         mcroth
# 119340       2
# 58023        3
# 46997        3
# 67214        1
# 153590       3

# %%
y.sample(5, random_state=seed)
# Out:
# 119340    0.845614
# 58023     0.270908
# 46997     0.412787
# 67214     0.576249
# 153590    0.310006
# Name: severidad_real, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=seed)

# %%
def optimize_params(estimator, X, y, cv, scoring=None, refit=True, **param_grid):
    t=time()
    
    # GridSearch over specified parameter values for an estimator
    grid_search_cv = GridSearchCV(estimator,
                                  param_grid,
                                  scoring=scoring,
                                  refit=refit,
                                  cv=cv,
                                  verbose=1,
                                  n_jobs=10,
                                  return_train_score=True).fit(X, y)

    cv_results = pd.DataFrame(grid_search_cv.cv_results_)

    # Drop the results for each validation split and sort by the validation metric
    labels = cv_results.filter(regex="split")
    by = cv_results.filter(regex="rank_test").columns[0]
    cv_results = cv_results.drop(labels, axis=1).sort_values(by)

    print(f'Time: {round(time()-t, 2)} seg.')
    display(cv_results)

    return grid_search_cv

# %%
n_splits = 4
n_repeats = 2

cv = RepeatedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=seed)

# %%
preprocessing = make_column_transformer(
        (StandardScaler(), numerical_variables),
        (OneHotEncoder(handle_unknown='ignore'), categorical_variables),
        remainder='passthrough'
)

# %% [markdown]
# ## Grid Search

# %% [markdown]
# ### Linear Regression

# %%
poly = PolynomialFeatures(include_bias=False)
linear_reg = Ridge(random_state=seed)
linear_reg_pipeline = make_pipeline(preprocessing, poly, linear_reg)

param_grid = {
    'polynomialfeatures__degree': [1, 2, 3],
    'ridge__alpha': [0.01, 0.1, 0.5, 1, 2, 10]
}

linear_reg_gs = optimize_params(linear_reg_pipeline, X_train, y_train, cv, scoring='r2', **param_grid)
# Out:
# Fitting 8 folds for each of 18 candidates, totalling 144 fits
# Time: 565.69 seg.
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 13      40.040815     20.915225         1.178427        0.296734
# 14      30.106780      3.333619         1.112334        0.064227
# 15      37.367767      4.954834         1.919485        1.198218
# 16      37.071441      6.282540         2.173924        0.966095
# 17      52.082184     16.748880         1.914617        1.498325
# 12     387.790188    164.849716         1.147330        0.295897
# 7        1.391587      0.067497         0.196363        0.026523
# 6        1.459190      0.064801         0.214640        0.018513
# 8        1.462244      0.082832         0.219760        0.016667
# 9        1.482839      0.054846         0.226309        0.018567
# 10       1.470867      0.032248         0.228328        0.014275
# 11       1.451444      0.064077         0.203242        0.015557
# 5        0.251997      0.007391         0.052881        0.003137
# 4        0.276013      0.014149         0.056335        0.009169
# 3        0.281239      0.009689         0.055929        0.001919
# 2        0.272245      0.009571         0.057893        0.003460
# 1        0.274289      0.067917         0.057586        0.005812
# 0        0.372028      0.007260         0.063358        0.008459
#
#    param_polynomialfeatures__degree param_ridge__alpha  \
# 13                                3                0.1
# 14                                3                0.5
# 15                                3                  1
# 16                                3                  2
# 17                                3                 10
# 12                                3               0.01
# 7                                 2                0.1
# 6                                 2               0.01
# 8                                 2                0.5
# 9                                 2                  1
# 10                                2                  2
# 11                                2                 10
# 5                                 1                 10
# 4                                 1                  2
# 3                                 1                  1
# 2                                 1                0.5
# 1                                 1                0.1
# 0                                 1               0.01
#
#                                                params  mean_test_score  \
# 13  {'polynomialfeatures__degree': 3, 'ridge__alph...         0.377136
# 14  {'polynomialfeatures__degree': 3, 'ridge__alph...         0.374343
# 15  {'polynomialfeatures__degree': 3, 'ridge__alph...         0.373488
# 16  {'polynomialfeatures__degree': 3, 'ridge__alph...         0.372326
# 17  {'polynomialfeatures__degree': 3, 'ridge__alph...         0.368162
# 12  {'polynomialfeatures__degree': 3, 'ridge__alph...         0.363046
# 7   {'polynomialfeatures__degree': 2, 'ridge__alph...         0.294344
# 6   {'polynomialfeatures__degree': 2, 'ridge__alph...         0.294339
# 8   {'polynomialfeatures__degree': 2, 'ridge__alph...         0.294311
# 9   {'polynomialfeatures__degree': 2, 'ridge__alph...         0.294295
# 10  {'polynomialfeatures__degree': 2, 'ridge__alph...         0.294272
# 11  {'polynomialfeatures__degree': 2, 'ridge__alph...         0.294152
# 5   {'polynomialfeatures__degree': 1, 'ridge__alph...         0.159908
# 4   {'polynomialfeatures__degree': 1, 'ridge__alph...         0.159908
# 3   {'polynomialfeatures__degree': 1, 'ridge__alph...         0.159908
# 2   {'polynomialfeatures__degree': 1, 'ridge__alph...         0.159908
# 1   {'polynomialfeatures__degree': 1, 'ridge__alph...         0.159908
# 0   {'polynomialfeatures__degree': 1, 'ridge__alph...         0.159908
#
#     std_test_score  rank_test_score  mean_train_score  std_train_score
# 13        0.003145                1          0.393530         0.000562
# 14        0.002965                2          0.389748         0.000529
# 15        0.002121                3          0.387783         0.000524
# 16        0.001986                4          0.385726         0.000547
# 17        0.002225                5          0.380343         0.000656
# 12        0.013850                6          0.396016         0.000531
# 7         0.003153                7          0.296912         0.001047
# 6         0.003155                8          0.296932         0.001048
# 8         0.003154                9          0.296877         0.001047
# 9         0.003158               10          0.296856         0.001047
# 10        0.003161               11          0.296822         0.001048
# 11        0.003131               12          0.296643         0.001050
# 5         0.003540               13          0.160247         0.001180
# 4         0.003542               14          0.160247         0.001180
# 3         0.003542               15          0.160247         0.001180
# 2         0.003542               16          0.160247         0.001180
# 1         0.003542               17          0.160247         0.001180
# 0         0.003542               18          0.160247         0.001180

# %% [markdown]
# ### KNeighbors

# %%
k_neighbors_reg = KNeighborsRegressor()
k_neighbours_reg_pipeline = make_pipeline(preprocessing, k_neighbors_reg)

param_grid = {
    'kneighborsregressor__n_neighbors': [5, 10, 20, 50, 100],
    'kneighborsregressor__weights': ['uniform', 'distance']
}

k_neighbors_reg_gs = optimize_params(k_neighbours_reg_pipeline, X_train, y_train, cv, scoring='r2', **param_grid)
# Out:
# Fitting 8 folds for each of 10 candidates, totalling 80 fits
# Time: 1204.7 seg.
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 5       0.109064      0.010895        36.104413        0.627193
# 3       0.176094      0.064612        37.319270        0.694311
# 7       0.115325      0.010626        36.145114        1.063845
# 4       0.126334      0.017113        36.125306        0.603631
# 2       0.146398      0.053391        39.052291        1.775319
# 6       0.115714      0.011893        36.798070        0.520943
# 9       0.122661      0.008741        36.688955        1.014024
# 8       0.114096      0.008244        36.743261        1.640566
# 1       0.186924      0.052661        41.261918        0.657586
# 0       0.143028      0.015617        39.954793        0.330159
#
#   param_kneighborsregressor__n_neighbors param_kneighborsregressor__weights  \
# 5                                     20                           distance
# 3                                     10                           distance
# 7                                     50                           distance
# 4                                     20                            uniform
# 2                                     10                            uniform
# 6                                     50                            uniform
# 9                                    100                           distance
# 8                                    100                            uniform
# 1                                      5                           distance
# 0                                      5                            uniform
#
#                                               params  mean_test_score  \
# 5  {'kneighborsregressor__n_neighbors': 20, 'knei...         0.402597
# 3  {'kneighborsregressor__n_neighbors': 10, 'knei...         0.394180
# 7  {'kneighborsregressor__n_neighbors': 50, 'knei...         0.390295
# 4  {'kneighborsregressor__n_neighbors': 20, 'knei...         0.390282
# 2  {'kneighborsregressor__n_neighbors': 10, 'knei...         0.385870
# 6  {'kneighborsregressor__n_neighbors': 50, 'knei...         0.374378
# 9  {'kneighborsregressor__n_neighbors': 100, 'kne...         0.373607
# 8  {'kneighborsregressor__n_neighbors': 100, 'kne...         0.356726
# 1  {'kneighborsregressor__n_neighbors': 5, 'kneig...         0.356700
# 0  {'kneighborsregressor__n_neighbors': 5, 'kneig...         0.352560
#
#    std_test_score  rank_test_score  mean_train_score  std_train_score
# 5        0.003619                1          1.000000     3.315900e-14
# 3        0.003806                2          1.000000     1.089603e-14
# 7        0.002747                3          1.000000     1.432198e-13
# 4        0.003577                4          0.450484     1.433049e-03
# 2        0.003866                5          0.500988     1.063657e-03
# 6        0.002643                6          0.400057     9.347390e-04
# 9        0.002664                7          1.000000     4.100923e-13
# 8        0.002653                8          0.369827     8.785020e-04
# 1        0.005074                9          1.000000     3.858923e-15
# 0        0.005337               10          0.572631     1.512176e-03

# %% [markdown]
# ### Decision Tree

# %%
decision_tree_reg = DecisionTreeRegressor(random_state=seed)
decision_tree_reg_pipeline = make_pipeline(preprocessing, decision_tree_reg)

param_grid = {
    'decisiontreeregressor__max_depth': [3, 5, 7, 10, None],
    'decisiontreeregressor__min_samples_split': [2, 50, 200],
    'decisiontreeregressor__criterion': ['squared_error', 'friedman_mse', 'poisson'],
    'decisiontreeregressor__ccp_alpha': [0, 0.0001, 0.001, 0.01, 0.1]
}

decision_tree_reg_gs = optimize_params(decision_tree_reg_pipeline, X_train, y_train, cv, scoring='r2', **param_grid)
# Out:
# Fitting 8 folds for each of 225 candidates, totalling 1800 fits
# Time: 1502.32 seg.
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 28        5.046501      0.151272         0.033228        0.008927
# 13        5.100879      0.110822         0.032455        0.006109
# 43        6.159351      0.115350         0.041011        0.005640
# 44        5.130538      0.169351         0.034449        0.009753
# 14        4.366225      0.232686         0.036934        0.006553
# ..             ...           ...              ...             ...
# 160       3.433759      0.072381         0.026728        0.006654
# 159       3.458890      0.065902         0.028911        0.006616
# 158       2.587472      0.056617         0.023014        0.002128
# 156       2.636034      0.074822         0.028827        0.005116
# 224       6.617276      0.163512         0.043796        0.007727
#
#     param_decisiontreeregressor__ccp_alpha  \
# 28                                       0
# 13                                       0
# 43                                       0
# 44                                       0
# 14                                       0
# ..                                     ...
# 160                                   0.01
# 159                                   0.01
# 158                                   0.01
# 156                                   0.01
# 224                                    0.1
#
#     param_decisiontreeregressor__criterion  \
# 28                            friedman_mse
# 13                           squared_error
# 43                                 poisson
# 44                                 poisson
# 14                           squared_error
# ..                                     ...
# 160                           friedman_mse
# 159                           friedman_mse
# 158                           friedman_mse
# 156                           friedman_mse
# 224                                poisson
#
#     param_decisiontreeregressor__max_depth  \
# 28                                    None
# 13                                    None
# 43                                    None
# 44                                    None
# 14                                    None
# ..                                     ...
# 160                                     10
# 159                                     10
# 158                                      7
# 156                                      7
# 224                                   None
#
#                                                 params  mean_test_score  \
# 28   {'decisiontreeregressor__ccp_alpha': 0, 'decis...         0.526107
# 13   {'decisiontreeregressor__ccp_alpha': 0, 'decis...         0.526011
# 43   {'decisiontreeregressor__ccp_alpha': 0, 'decis...         0.525571
# 44   {'decisiontreeregressor__ccp_alpha': 0, 'decis...         0.492008
# 14   {'decisiontreeregressor__ccp_alpha': 0, 'decis...         0.491750
# ..                                                 ...              ...
# 160  {'decisiontreeregressor__ccp_alpha': 0.01, 'de...        -0.000031
# 159  {'decisiontreeregressor__ccp_alpha': 0.01, 'de...        -0.000031
# 158  {'decisiontreeregressor__ccp_alpha': 0.01, 'de...        -0.000031
# 156  {'decisiontreeregressor__ccp_alpha': 0.01, 'de...        -0.000031
# 224  {'decisiontreeregressor__ccp_alpha': 0.1, 'dec...        -0.000031
#
#      std_test_score  rank_test_score  mean_train_score  std_train_score
# 28         0.006673                1      7.199219e-01     2.555821e-03
# 13         0.006812                2      7.199219e-01     2.555821e-03
# 43         0.007287                3      7.217258e-01     3.646081e-03
# 44         0.006260                4      5.633251e-01     3.397572e-03
# 14         0.006309                5      5.612105e-01     1.714298e-03
# ..              ...              ...               ...              ...
# 160        0.000036              136      1.387779e-17     1.029204e-16
# 159        0.000036              136      1.387779e-17     1.029204e-16
# 158        0.000036              136      1.387779e-17     1.029204e-16
# 156        0.000036              136      1.387779e-17     1.029204e-16
# 224        0.000036              136      1.387779e-17     1.029204e-16
#
# [225 rows x 13 columns]

# %% [markdown]
# ### Random Forest

# %%
random_forest_reg = RandomForestRegressor(random_state=seed)
random_forest_reg_pipeline = make_pipeline(preprocessing, random_forest_reg)

param_grid = {
    'randomforestregressor__n_estimators': [10, 25, 50],
    'randomforestregressor__max_depth': [3, 5, 7, 10, None]
}

random_forest_reg_gs = optimize_params(random_forest_reg_pipeline, X_train, y_train, cv, scoring='r2', **param_grid)
# Out:
# Fitting 8 folds for each of 15 candidates, totalling 120 fits
# Time: 1080.51 seg.
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 14     217.987472      9.501452         0.640658        0.072109
# 13     134.171816      1.191305         0.451335        0.042784
# 12      55.913423      0.534889         0.200781        0.020153
# 11     133.636051      0.735355         0.245775        0.020334
# 10      68.015156      0.245512         0.137034        0.015410
# 9       27.572605      0.184246         0.069719        0.012505
# 8       98.202944      0.387704         0.186118        0.016881
# 7       49.977098      0.193271         0.101131        0.016585
# 6       19.954040      0.317576         0.060874        0.013096
# 5       72.085611      0.376602         0.147878        0.015500
# 4       36.908285      0.315362         0.084772        0.007514
# 3       14.563701      0.230130         0.056014        0.008362
# 2       43.592503      0.156352         0.121334        0.011090
# 1       22.122910      0.231206         0.079097        0.011857
# 0        8.701752      0.149920         0.101982        0.037063
#
#    param_randomforestregressor__max_depth  \
# 14                                   None
# 13                                   None
# 12                                   None
# 11                                     10
# 10                                     10
# 9                                      10
# 8                                       7
# 7                                       7
# 6                                       7
# 5                                       5
# 4                                       5
# 3                                       5
# 2                                       3
# 1                                       3
# 0                                       3
#
#    param_randomforestregressor__n_estimators  \
# 14                                        50
# 13                                        25
# 12                                        10
# 11                                        50
# 10                                        25
# 9                                         10
# 8                                         50
# 7                                         25
# 6                                         10
# 5                                         50
# 4                                         25
# 3                                         10
# 2                                         50
# 1                                         25
# 0                                         10
#
#                                                params  mean_test_score  \
# 14  {'randomforestregressor__max_depth': None, 'ra...         0.696175
# 13  {'randomforestregressor__max_depth': None, 'ra...         0.688685
# 12  {'randomforestregressor__max_depth': None, 'ra...         0.665966
# 11  {'randomforestregressor__max_depth': 10, 'rand...         0.503961
# 10  {'randomforestregressor__max_depth': 10, 'rand...         0.501109
# 9   {'randomforestregressor__max_depth': 10, 'rand...         0.494480
# 8   {'randomforestregressor__max_depth': 7, 'rando...         0.363430
# 7   {'randomforestregressor__max_depth': 7, 'rando...         0.361419
# 6   {'randomforestregressor__max_depth': 7, 'rando...         0.357213
# 5   {'randomforestregressor__max_depth': 5, 'rando...         0.267666
# 4   {'randomforestregressor__max_depth': 5, 'rando...         0.266768
# 3   {'randomforestregressor__max_depth': 5, 'rando...         0.263589
# 2   {'randomforestregressor__max_depth': 3, 'rando...         0.163014
# 1   {'randomforestregressor__max_depth': 3, 'rando...         0.162233
# 0   {'randomforestregressor__max_depth': 3, 'rando...         0.160825
#
#     std_test_score  rank_test_score  mean_train_score  std_train_score
# 14        0.003270                1          0.955699         0.000138
# 13        0.003413                2          0.951485         0.000133
# 12        0.004384                3          0.938738         0.000295
# 11        0.004757                4          0.545528         0.002908
# 10        0.005459                5          0.542642         0.003379
# 9         0.006300                6          0.536179         0.004224
# 8         0.004306                7          0.376014         0.002262
# 7         0.005385                8          0.374100         0.003398
# 6         0.006144                9          0.369984         0.004554
# 5         0.003105               10          0.272108         0.001521
# 4         0.003277               11          0.271301         0.001533
# 3         0.003651               12          0.268317         0.002876
# 2         0.002076               13          0.165068         0.002497
# 1         0.002397               14          0.164402         0.002484
# 0         0.004157               15          0.163407         0.004720

# %% [markdown]
# ### XGBoost

# %%
xgb_reg = XGBRegressor(random_state=seed)
xgb_reg_pipeline = make_pipeline(preprocessing, xgb_reg)

param_grid = {
    'xgbregressor__n_estimators': [10, 25, 50, 100],
    'xgbregressor__max_depth': [3, 5, 7, 10, None],
    'xgbregressor__learning_rate': [0.001, 0.005, 0.01, 0.05, 0.1, 0.2]
}

xgb_reg_gs = optimize_params(xgb_reg_pipeline, X_train, y_train, cv, scoring='r2', **param_grid)
# Out:
# Fitting 8 folds for each of 120 candidates, totalling 960 fits
# Time: 251.98 seg.
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 115       6.384209      0.737279         0.380800        0.044614
# 95        6.838453      0.616383         0.399817        0.046864
# 114       4.363920      0.420120         0.201637        0.026717
# 75        8.806289      0.826498         0.457196        0.049709
# 94        4.575071      0.378477         0.213526        0.023979
# ..             ...           ...              ...             ...
# 1         0.814251      0.018260         0.042013        0.004644
# 8         0.717513      0.035032         0.043664        0.009188
# 16        0.939293      0.019620         0.070404        0.010968
# 4         0.572232      0.063041         0.038998        0.006472
# 0         0.640512      0.044057         0.048822        0.004287
#
#     param_xgbregressor__learning_rate param_xgbregressor__max_depth  \
# 115                               0.2                            10
# 95                                0.1                            10
# 114                               0.2                            10
# 75                               0.05                            10
# 94                                0.1                            10
# ..                                ...                           ...
# 1                               0.001                             3
# 8                               0.001                             7
# 16                              0.001                          None
# 4                               0.001                             5
# 0                               0.001                             3
#
#     param_xgbregressor__n_estimators  \
# 115                              100
# 95                               100
# 114                               50
# 75                               100
# 94                                50
# ..                               ...
# 1                                 25
# 8                                 10
# 16                                10
# 4                                 10
# 0                                 10
#
#                                                 params  mean_test_score  \
# 115  {'xgbregressor__learning_rate': 0.2, 'xgbregre...         0.646875
# 95   {'xgbregressor__learning_rate': 0.1, 'xgbregre...         0.634160
# 114  {'xgbregressor__learning_rate': 0.2, 'xgbregre...         0.627759
# 75   {'xgbregressor__learning_rate': 0.05, 'xgbregr...         0.607905
# 94   {'xgbregressor__learning_rate': 0.1, 'xgbregre...         0.607413
# ..                                                 ...              ...
# 1    {'xgbregressor__learning_rate': 0.001, 'xgbreg...         0.007196
# 8    {'xgbregressor__learning_rate': 0.001, 'xgbreg...         0.006350
# 16   {'xgbregressor__learning_rate': 0.001, 'xgbreg...         0.005555
# 4    {'xgbregressor__learning_rate': 0.001, 'xgbreg...         0.004798
# 0    {'xgbregressor__learning_rate': 0.001, 'xgbreg...         0.002894
#
#      std_test_score  rank_test_score  mean_train_score  std_train_score
# 115        0.004021                1          0.837901         0.003577
# 95         0.003125                2          0.769770         0.002125
# 114        0.004357                3          0.767062         0.004974
# 75         0.002535                4          0.712821         0.003404
# 94         0.003199                5          0.713196         0.002370
# ..              ...              ...               ...              ...
# 1          0.000049              116          0.007266         0.000071
# 8          0.000164              117          0.006502         0.000217
# 16         0.000189              118          0.005662         0.000230
# 4          0.000107              119          0.004877         0.000129
# 0          0.000046              120          0.002942         0.000015
#
# [120 rows x 13 columns]

# %% [markdown]
# ### SGD

# %%
sgd_reg = SGDRegressor(random_state=seed)
sgd_reg_pipeline = make_pipeline(preprocessing, sgd_reg)

param_grid = {
    'sgdregressor__alpha': [0.0001, 0.001, 0.01, 0.1, 0.2, 0.5, 0.8],
    'sgdregressor__max_iter': [50, 100, 500, 1000],
    'sgdregressor__loss': ['squared_error', 'huber', 'epsilon_insensitive', 'squared_epsilon_insensitive']
}

sgd_reg_gs = optimize_params(sgd_reg_pipeline, X_train, y_train, cv, scoring='r2', **param_grid)
# Out:
# Fitting 8 folds for each of 240 candidates, totalling 1920 fits
# Time: 111.33 seg.
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.367657      0.019628         0.062427        0.034286
# 1         0.404428      0.024598         0.042106        0.013183
# 2         0.389496      0.036760         0.040738        0.009770
# 3         0.432062      0.047194         0.047520        0.009703
# 4         0.426448      0.047917         0.036334        0.005066
# ..             ...           ...              ...             ...
# 225       0.412119      0.051163         0.038739        0.013656
# 224       0.441676      0.056620         0.036228        0.004448
# 223       0.391161      0.042848         0.039938        0.009523
# 227       0.406121      0.047070         0.037053        0.007755
# 222       0.405252      0.046872         0.039969        0.012356
#
#     param_sgdregressor__alpha param_sgdregressor__loss  \
# 0                    0.000001            squared_error
# 1                    0.000001            squared_error
# 2                    0.000001            squared_error
# 3                    0.000001            squared_error
# 4                    0.000001            squared_error
# ..                        ...                      ...
# 225                       0.1                    huber
# 224                       0.1                    huber
# 223                       0.1                    huber
# 227                       0.1                    huber
# 222                       0.1                    huber
#
#     param_sgdregressor__max_iter  \
# 0                             50
# 1                            100
# 2                            300
# 3                            500
# 4                           1000
# ..                           ...
# 225                          500
# 224                          300
# 223                          100
# 227                         2000
# 222                           50
#
#                                                 params  mean_test_score  \
# 0    {'sgdregressor__alpha': 1e-06, 'sgdregressor__...         0.158093
# 1    {'sgdregressor__alpha': 1e-06, 'sgdregressor__...         0.158093
# 2    {'sgdregressor__alpha': 1e-06, 'sgdregressor__...         0.158093
# 3    {'sgdregressor__alpha': 1e-06, 'sgdregressor__...         0.158093
# 4    {'sgdregressor__alpha': 1e-06, 'sgdregressor__...         0.158093
# ..                                                 ...              ...
# 225  {'sgdregressor__alpha': 0.1, 'sgdregressor__lo...         0.125366
# 224  {'sgdregressor__alpha': 0.1, 'sgdregressor__lo...         0.125366
# 223  {'sgdregressor__alpha': 0.1, 'sgdregressor__lo...         0.125366
# 227  {'sgdregressor__alpha': 0.1, 'sgdregressor__lo...         0.125366
# 222  {'sgdregressor__alpha': 0.1, 'sgdregressor__lo...         0.125366
#
#      std_test_score  rank_test_score  mean_train_score  std_train_score
# 0          0.003779                1          0.158000         0.001420
# 1          0.003779                1          0.158000         0.001420
# 2          0.003779                1          0.158000         0.001420
# 3          0.003779                1          0.158000         0.001420
# 4          0.003779                1          0.158000         0.001420
# ..              ...              ...               ...              ...
# 225        0.004004              235          0.125486         0.004313
# 224        0.004004              235          0.125486         0.004313
# 223        0.004004              235          0.125486         0.004313
# 227        0.004004              235          0.125486         0.004313
# 222        0.004004              235          0.125486         0.004313
#
# [240 rows x 13 columns]

# %% [markdown]
# ## Evaluación

# %%
reg_dict = {
    'Regresion lineal': linear_reg_gs,
    'KNeighbors' : k_neighbors_reg_gs,
    'Arbol de decision': decision_tree_reg_gs,
    'Random Forest': random_forest_reg_gs,
    'XGBoost': xgb_reg_gs,
    'SGD': sgd_reg_gs
}


df_results_class = pd.DataFrame({
    'Modelo': reg_dict.keys(),
    'Mejor puntuación': [gs.best_score_ for gs in reg_dict.values()]
})
df_results_class = df_results_class.sort_values(by='Mejor puntuación', ascending=False)
df_results_class
# Out:
#               Modelo  Mejor puntuacion
# 3      Random Forest          0.696175
# 4            XGBoost          0.646875
# 2  Arbol de decision          0.526107
# 1         KNeighbors          0.402597
# 0   Regresion lineal          0.377136
# 5                SGD          0.158093

# %%
model = random_forest_reg_gs.best_estimator_
model_path = os.path.join('models', 'experiment_1', 'model_reg.joblib')
dump(model, model_path)
# Out:
# ['models\\model_1_reg.joblib']

# %%
model_path = os.path.join('models', 'experiment_1', 'model_reg.joblib')
model = load(model_path)
pred = model.predict(X_test)

print(f"""Métricas predicción del test
R2:  {r2_score(y_test, pred)}
MSE: {mean_squared_error(y_test, pred)}
MAE: {mean_absolute_error(y_test, pred)}""")
# Out:
# Métricas predicción del test
# R2:  0.724605944426127
# MSE: 0.008783141496746506
# MAE: 0.06940586333961964

# %% [markdown]
# # Clasificación

# %%
X = df[variables]
y = df[target_discrete]

# %%
X.sample(5, random_state=seed)
# Out:
#           elevacion   slope  orientacion_sen  orientacion_cos  altura  \
# 119340  1024.904053  15.177         0.994650         0.103298     9.0
# 58023    505.352997  25.718         0.206331         0.978482     3.0
# 46997    388.710999  31.593        -0.984000         0.178167     1.0
# 67214   1063.177002  22.364         0.901304        -0.433188     2.0
# 153590   507.516998  13.911         0.872081         0.489362     3.0
#
#              lfcc   anomalia       dpv  vel_media_viento  erodi  inflam  \
# 119340  46.956501  73.561211  2.246882          2.916394      4       3
# 58023   19.892401  86.961823  2.385298          4.876472      1       4
# 46997    0.956900  79.168137  2.319516          5.026659      2       4
# 67214    7.424201  50.321835  0.349119          2.470344      1       4
# 153590  32.275799  72.893860  1.469779          3.393716      3       4
#
#         mcroth
# 119340       2
# 58023        3
# 46997        3
# 67214        1
# 153590       3

# %%
y.sample(5, random_state=seed)
# Out:
# 119340    3
# 58023     1
# 46997     1
# 67214     2
# 153590    1
# Name: severidad_discreta, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=seed)

# %%
def optimize_params(estimator, X, y, cv, scoring=None, refit=True, **param_grid):
    t=time()
    """Exhaustive search over specified parameter values for an estimator."""
    grid_search_cv = GridSearchCV(estimator,
                                  param_grid,
                                  scoring=scoring,
                                  refit=refit,
                                  cv=cv,
                                  verbose=1,
                                  n_jobs=10,
                                  return_train_score=True).fit(X, y)

    cv_results = pd.DataFrame(grid_search_cv.cv_results_)

    # Drop the results for each validation split and sort by the refit metric
    labels = cv_results.filter(regex="split")
    by = cv_results.filter(regex="rank_test").columns[0]
    cv_results = cv_results.drop(labels, axis=1).sort_values(by)

    print(f'Time: {round(time()-t, 2)} seg.')
    display(cv_results)

    return grid_search_cv

# %%
n_splits = 4
n_repeats = 2

cv = RepeatedStratifiedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=seed)

# %%
preprocessing = make_column_transformer(
        (StandardScaler(), numerical_variables),
        (OneHotEncoder(handle_unknown='ignore'), categorical_variables),
        remainder='passthrough'
)

# %% [markdown]
# ## Grid Search

# %% [markdown]
# ### Logistic Regression

# %%
poly = PolynomialFeatures(include_bias=False)
logistic_reg = LogisticRegression(random_state=seed)
logistic_reg_pipeline = make_pipeline(preprocessing, poly, logistic_reg)

param_grid = {
    'polynomialfeatures__degree': [1, 2],
    'logisticregression__C': [0.01, 0.1, 1, 2, 5, 10],
    'logisticregression__max_iter': [100, 200]
}

logistic_reg_gs = optimize_params(logistic_reg_pipeline, X_train, y_train, cv, scoring='f1_weighted', **param_grid)
# Out:
# Fitting 8 folds for each of 30 candidates, totalling 240 fits
# Time: 2149.01 seg.
# c:\Users\Alejandro.Martinez\AppData\Local\miniconda3\envs\nuevoEntorno\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 11     443.240402    458.673276         1.720291        0.541496
# 29     228.512113     40.517195         1.033737        0.322400
# 5      311.529017    379.944671         3.414598        1.811152
# 17     230.082301    157.178977         1.828555        1.312539
# 23     244.779746    189.291701         2.558950        1.699420
# 8       92.223264     12.850660         1.586185        0.574931
# 20     133.406392    108.706183         3.424112        2.151539
# 26     136.369322    111.959254         1.570215        0.290275
# 14     128.175350     92.807931         2.451749        1.182782
# 2      285.077466    231.863905         1.689844        0.226057
# 10      25.401232      4.044996         0.290989        0.079624
# 28      28.365707      1.519883         0.539268        0.300209
# 16      26.799615      3.076006         0.282111        0.050943
# 22      22.745873      2.091171         0.239631        0.045195
# 4       27.121797      1.800328         0.314661        0.052791
# 7        9.623979      0.548389         0.187717        0.015348
# 25      11.689098      1.592055         0.238808        0.056564
# 13      11.834889      1.307513         0.254690        0.042892
# 1       12.309886      0.334129         0.233624        0.051430
# 19      15.210869      1.983038         0.962549        1.684181
# 12       3.256124      0.170361         0.068659        0.004694
# 6        2.398203      0.739666         0.045668        0.018891
# 9        3.646993      1.098701         0.063991        0.012011
# 15       3.853473      0.393957         0.076158        0.010194
# 24       3.114338      0.227730         0.085239        0.036629
# 27       3.276786      0.297245         0.065992        0.004291
# 18       3.287964      0.096440         0.066879        0.007701
# 21       3.422109      0.240194         0.069724        0.007608
# 3        9.913028      7.923142         0.088314        0.014512
# 0        2.668037      0.060699         0.058908        0.002719
#
#    param_logisticregression__C param_logisticregression__max_iter  \
# 11                           1                                200
# 29                          10                                200
# 5                          0.1                                200
# 17                           2                                200
# 23                           5                                200
# 8                            1                                100
# 20                           5                                100
# 26                          10                                100
# 14                           2                                100
# 2                          0.1                                100
# 10                           1                                200
# 28                          10                                200
# 16                           2                                200
# 22                           5                                200
# 4                          0.1                                200
# 7                            1                                100
# 25                          10                                100
# 13                           2                                100
# 1                          0.1                                100
# 19                           5                                100
# 12                           2                                100
# 6                            1                                100
# 9                            1                                200
# 15                           2                                200
# 24                          10                                100
# 27                          10                                200
# 18                           5                                100
# 21                           5                                200
# 3                          0.1                                200
# 0                          0.1                                100
#
#    param_polynomialfeatures__degree  \
# 11                                3
# 29                                3
# 5                                 3
# 17                                3
# 23                                3
# 8                                 3
# 20                                3
# 26                                3
# 14                                3
# 2                                 3
# 10                                2
# 28                                2
# 16                                2
# 22                                2
# 4                                 2
# 7                                 2
# 25                                2
# 13                                2
# 1                                 2
# 19                                2
# 12                                1
# 6                                 1
# 9                                 1
# 15                                1
# 24                                1
# 27                                1
# 18                                1
# 21                                1
# 3                                 1
# 0                                 1
#
#                                                params  mean_test_score  \
# 11  {'logisticregression__C': 1, 'logisticregressi...         0.518241
# 29  {'logisticregression__C': 10, 'logisticregress...         0.517944
# 5   {'logisticregression__C': 0.1, 'logisticregres...         0.517870
# 17  {'logisticregression__C': 2, 'logisticregressi...         0.517860
# 23  {'logisticregression__C': 5, 'logisticregressi...         0.517744
# 8   {'logisticregression__C': 1, 'logisticregressi...         0.512918
# 20  {'logisticregression__C': 5, 'logisticregressi...         0.512706
# 26  {'logisticregression__C': 10, 'logisticregress...         0.512531
# 14  {'logisticregression__C': 2, 'logisticregressi...         0.512311
# 2   {'logisticregression__C': 0.1, 'logisticregres...         0.511939
# 10  {'logisticregression__C': 1, 'logisticregressi...         0.493205
# 28  {'logisticregression__C': 10, 'logisticregress...         0.493168
# 16  {'logisticregression__C': 2, 'logisticregressi...         0.493104
# 22  {'logisticregression__C': 5, 'logisticregressi...         0.492949
# 4   {'logisticregression__C': 0.1, 'logisticregres...         0.492478
# 7   {'logisticregression__C': 1, 'logisticregressi...         0.491141
# 25  {'logisticregression__C': 10, 'logisticregress...         0.491067
# 13  {'logisticregression__C': 2, 'logisticregressi...         0.491010
# 1   {'logisticregression__C': 0.1, 'logisticregres...         0.490963
# 19  {'logisticregression__C': 5, 'logisticregressi...         0.490710
# 12  {'logisticregression__C': 2, 'logisticregressi...         0.412796
# 6   {'logisticregression__C': 1, 'logisticregressi...         0.412782
# 9   {'logisticregression__C': 1, 'logisticregressi...         0.412778
# 15  {'logisticregression__C': 2, 'logisticregressi...         0.412761
# 24  {'logisticregression__C': 10, 'logisticregress...         0.412758
# 27  {'logisticregression__C': 10, 'logisticregress...         0.412750
# 18  {'logisticregression__C': 5, 'logisticregressi...         0.412749
# 21  {'logisticregression__C': 5, 'logisticregressi...         0.412735
# 3   {'logisticregression__C': 0.1, 'logisticregres...         0.412563
# 0   {'logisticregression__C': 0.1, 'logisticregres...         0.412496
#
#     std_test_score  rank_test_score  mean_train_score  std_train_score
# 11        0.001960                1          0.530237         0.000945
# 29        0.002143                2          0.530564         0.000884
# 5         0.002063                3          0.530275         0.001022
# 17        0.001967                4          0.530779         0.000679
# 23        0.001749                5          0.530293         0.001097
# 8         0.002082                6          0.523292         0.000575
# 20        0.001557                7          0.523476         0.000826
# 26        0.002074                8          0.523189         0.000789
# 14        0.002036                9          0.523351         0.000603
# 2         0.001989               10          0.523031         0.001014
# 10        0.002077               11          0.496770         0.000901
# 28        0.002301               12          0.496811         0.001011
# 16        0.002201               13          0.496813         0.000963
# 22        0.001975               14          0.496853         0.000971
# 4         0.002167               15          0.495951         0.000902
# 7         0.002156               16          0.494296         0.000955
# 25        0.002383               17          0.494345         0.001042
# 13        0.002511               18          0.494347         0.000825
# 1         0.002481               19          0.494123         0.000883
# 19        0.002500               20          0.494083         0.000836
# 12        0.002938               21          0.413495         0.000854
# 6         0.002938               22          0.413471         0.000863
# 9         0.002921               23          0.413463         0.000851
# 15        0.002960               24          0.413490         0.000879
# 24        0.002949               25          0.413488         0.000857
# 27        0.002954               26          0.413492         0.000855
# 18        0.002970               27          0.413502         0.000844
# 21        0.002960               28          0.413498         0.000856
# 3         0.002966               29          0.413335         0.000914
# 0         0.002817               30          0.413283         0.000904

# %% [markdown]
# ### KNeighbors

# %%
k_neighbors_class = KNeighborsClassifier()
k_neighbours_class_pipeline = make_pipeline(preprocessing, k_neighbors_class)

param_grid = {
    'kneighborsclassifier__n_neighbors': [5, 10, 20, 50, 100],
    'kneighborsclassifier__weights': ['uniform', 'distance']
}

k_neighbors_class_gs = optimize_params(k_neighbours_class_pipeline, X_train, y_train, cv, scoring='f1_weighted', **param_grid)
# Out:
# Fitting 8 folds for each of 10 candidates, totalling 80 fits
# Time: 1368.94 seg.
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 5       0.126400      0.012780        42.660717        0.423654
# 7       0.129149      0.019783        41.841677        0.432103
# 4       0.122472      0.012842        43.237787        0.223263
# 9       0.127509      0.017777        43.637817        0.285656
# 3       0.128110      0.009401        43.875219        0.403632
# 6       0.127023      0.009336        42.316413        0.852796
# 2       0.122265      0.007661        42.922589        1.112874
# 8       0.134658      0.012356        42.982573        0.607287
# 1       0.120996      0.012453        41.818116        0.517395
# 0       0.135024      0.023822        42.122886        0.337946
#
#   param_kneighborsclassifier__n_neighbors param_kneighborsclassifier__weights  \
# 5                                      20                            distance
# 7                                      50                            distance
# 4                                      20                             uniform
# 9                                     100                            distance
# 3                                      10                            distance
# 6                                      50                             uniform
# 2                                      10                             uniform
# 8                                     100                             uniform
# 1                                       5                            distance
# 0                                       5                             uniform
#
#                                               params  mean_test_score  \
# 5  {'kneighborsclassifier__n_neighbors': 20, 'kne...         0.526210
# 7  {'kneighborsclassifier__n_neighbors': 50, 'kne...         0.524804
# 4  {'kneighborsclassifier__n_neighbors': 20, 'kne...         0.521357
# 9  {'kneighborsclassifier__n_neighbors': 100, 'kn...         0.518494
# 3  {'kneighborsclassifier__n_neighbors': 10, 'kne...         0.517919
# 6  {'kneighborsclassifier__n_neighbors': 50, 'kne...         0.517525
# 2  {'kneighborsclassifier__n_neighbors': 10, 'kne...         0.514632
# 8  {'kneighborsclassifier__n_neighbors': 100, 'kn...         0.509992
# 1  {'kneighborsclassifier__n_neighbors': 5, 'knei...         0.503075
# 0  {'kneighborsclassifier__n_neighbors': 5, 'knei...         0.499740
#
#    std_test_score  rank_test_score  mean_train_score  std_train_score
# 5        0.002100                1          1.000000         0.000000
# 7        0.002560                2          1.000000         0.000000
# 4        0.002475                3          0.576024         0.000939
# 9        0.002023                4          1.000000         0.000000
# 3        0.002027                5          1.000000         0.000000
# 6        0.002922                6          0.543023         0.000762
# 2        0.001903                7          0.608842         0.001116
# 8        0.002022                8          0.523552         0.000835
# 1        0.002736                9          1.000000         0.000000
# 0        0.002709               10          0.658221         0.000993

# %% [markdown]
# ### Decision Tree

# %%
decision_tree_class = DecisionTreeClassifier(random_state=seed)
decision_tree_class_pipeline = make_pipeline(preprocessing, decision_tree_class)

param_grid = {
    'decisiontreeclassifier__max_depth': [3, 5, 7, 10, None],
    'decisiontreeclassifier__min_samples_split': [2, 50, 200],
    'decisiontreeclassifier__criterion': ['entropy', 'gini'],
    'decisiontreeclassifier__ccp_alpha': [0, 0.0001, 0.001, 0.01, 0.1]
}

decision_tree_class_gs = optimize_params(decision_tree_class_pipeline, X_train, y_train, cv, scoring='f1_weighted', **param_grid)
# Out:
# Fitting 8 folds for each of 150 candidates, totalling 1200 fits
# Time: 535.27 seg.
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 42       11.770180      0.160472         0.054351        0.010750
# 43        7.806605      0.211261         0.054392        0.010480
# 13        7.461764      0.124419         0.057015        0.009566
# 28        5.518354      0.083520         0.055263        0.005500
# 12        8.581525      0.110795         0.053660        0.010436
# ..             ...           ...              ...             ...
# 121       1.741134      0.044919         0.045847        0.007936
# 120       1.727384      0.034572         0.043254        0.007419
# 148       5.690282      0.074390         0.045387        0.009387
# 133       7.855267      0.140384         0.046464        0.006132
# 149       4.536227      0.124929         0.042887        0.006681
#
#     param_decisiontreeclassifier__ccp_alpha  \
# 42                                   0.0001
# 43                                   0.0001
# 13                                        0
# 28                                        0
# 12                                        0
# ..                                      ...
# 121                                     0.1
# 120                                     0.1
# 148                                     0.1
# 133                                     0.1
# 149                                     0.1
#
#     param_decisiontreeclassifier__criterion  \
# 42                                  entropy
# 43                                  entropy
# 13                                  entropy
# 28                                     gini
# 12                                  entropy
# ..                                      ...
# 121                                 entropy
# 120                                 entropy
# 148                                    gini
# 133                                 entropy
# 149                                    gini
#
#     param_decisiontreeclassifier__max_depth  \
# 42                                     None
# 43                                     None
# 13                                     None
# 28                                     None
# 12                                     None
# ..                                      ...
# 121                                       3
# 120                                       3
# 148                                    None
# 133                                    None
# 149                                    None
#
#                                                 params  mean_test_score  \
# 42   {'decisiontreeclassifier__ccp_alpha': 0.0001, ...         0.581348
# 43   {'decisiontreeclassifier__ccp_alpha': 0.0001, ...         0.574542
# 13   {'decisiontreeclassifier__ccp_alpha': 0, 'deci...         0.571682
# 28   {'decisiontreeclassifier__ccp_alpha': 0, 'deci...         0.568135
# 12   {'decisiontreeclassifier__ccp_alpha': 0, 'deci...         0.567436
# ..                                                 ...              ...
# 121  {'decisiontreeclassifier__ccp_alpha': 0.1, 'de...         0.206183
# 120  {'decisiontreeclassifier__ccp_alpha': 0.1, 'de...         0.206183
# 148  {'decisiontreeclassifier__ccp_alpha': 0.1, 'de...         0.206183
# 133  {'decisiontreeclassifier__ccp_alpha': 0.1, 'de...         0.206183
# 149  {'decisiontreeclassifier__ccp_alpha': 0.1, 'de...         0.206183
#
#      std_test_score  rank_test_score  mean_train_score  std_train_score
# 42         0.003109                1          0.698796         0.002230
# 43         0.002661                2          0.663367         0.002057
# 13         0.001683                3          0.691800         0.001180
# 28         0.002630                4          0.705379         0.001407
# 12         0.002638                5          1.000000         0.000000
# ..              ...              ...               ...              ...
# 121        0.000013              121          0.206183         0.000004
# 120        0.000013              121          0.206183         0.000004
# 148        0.000013              121          0.206183         0.000004
# 133        0.000013              121          0.206183         0.000004
# 149        0.000013              121          0.206183         0.000004
#
# [150 rows x 13 columns]

# %% [markdown]
# ### Random Forest

# %%
random_forest_class = RandomForestClassifier(random_state=seed)
random_forest_class_pipeline = make_pipeline(preprocessing, random_forest_class)

param_grid = {
    'randomforestclassifier__n_estimators': [10, 25, 50],
    'randomforestclassifier__max_depth': [3, 5, 7, None],
    'randomforestclassifier__criterion': ['entropy', 'gini'],
}

random_forest_class_gs = optimize_params(random_forest_class_pipeline, X_train, y_train, cv, scoring='f1_weighted', **param_grid)
# Out:
# Fitting 8 folds for each of 24 candidates, totalling 192 fits
# Time: 394.78 seg.
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 11      67.804655      0.547450         0.808632        0.064649
# 23      42.825474      1.692210         0.607352        0.064526
# 10      32.633367      0.759254         0.409323        0.023843
# 22      26.550581      0.243329         0.425691        0.027004
# 9       13.566570      0.529937         0.184690        0.021004
# 21      11.265668      0.151762         0.191543        0.017305
# 7       14.567633      0.164105         0.200347        0.024862
# 8       28.424646      0.206760         0.310892        0.015575
# 20      21.790407      0.170052         0.305204        0.017882
# 19      11.153449      0.158048         0.175459        0.004652
# 6        6.024963      0.125892         0.104324        0.016599
# 18       4.720462      0.190227         0.106969        0.005876
# 16       8.416780      0.087570         0.159266        0.007622
# 17      16.904842      0.145434         0.274189        0.014172
# 15       3.534193      0.210811         0.097055        0.009582
# 4       10.931209      0.093764         0.156815        0.006140
# 3        4.624015      0.089126         0.101899        0.012851
# 5       21.414923      0.274112         0.263353        0.015411
# 12       2.122593      0.046038         0.081944        0.013818
# 0        3.408884      0.049504         0.103122        0.008576
# 1        7.446161      0.184224         0.155889        0.009253
# 13       4.982832      0.079254         0.136482        0.006055
# 2       14.073739      0.251336         0.240999        0.012671
# 14       9.911060      0.127036         0.234483        0.027995
#
#    param_randomforestclassifier__criterion  \
# 11                                 entropy
# 23                                    gini
# 10                                 entropy
# 22                                    gini
# 9                                  entropy
# 21                                    gini
# 7                                  entropy
# 8                                  entropy
# 20                                    gini
# 19                                    gini
# 6                                  entropy
# 18                                    gini
# 16                                    gini
# 17                                    gini
# 15                                    gini
# 4                                  entropy
# 3                                  entropy
# 5                                  entropy
# 12                                    gini
# 0                                  entropy
# 1                                  entropy
# 13                                    gini
# 2                                  entropy
# 14                                    gini
#
#    param_randomforestclassifier__max_depth  \
# 11                                    None
# 23                                    None
# 10                                    None
# 22                                    None
# 9                                     None
# 21                                    None
# 7                                        7
# 8                                        7
# 20                                       7
# 19                                       7
# 6                                        7
# 18                                       7
# 16                                       5
# 17                                       5
# 15                                       5
# 4                                        5
# 3                                        5
# 5                                        5
# 12                                       3
# 0                                        3
# 1                                        3
# 13                                       3
# 2                                        3
# 14                                       3
#
#    param_randomforestclassifier__n_estimators  \
# 11                                         50
# 23                                         50
# 10                                         25
# 22                                         25
# 9                                          10
# 21                                         10
# 7                                          25
# 8                                          50
# 20                                         50
# 19                                         25
# 6                                          10
# 18                                         10
# 16                                         25
# 17                                         50
# 15                                         10
# 4                                          25
# 3                                          10
# 5                                          50
# 12                                         10
# 0                                          10
# 1                                          25
# 13                                         25
# 2                                          50
# 14                                         50
#
#                                                params  mean_test_score  \
# 11  {'randomforestclassifier__criterion': 'entropy...         0.647980
# 23  {'randomforestclassifier__criterion': 'gini', ...         0.646736
# 10  {'randomforestclassifier__criterion': 'entropy...         0.638860
# 22  {'randomforestclassifier__criterion': 'gini', ...         0.637840
# 9   {'randomforestclassifier__criterion': 'entropy...         0.616763
# 21  {'randomforestclassifier__criterion': 'gini', ...         0.613562
# 7   {'randomforestclassifier__criterion': 'entropy...         0.501909
# 8   {'randomforestclassifier__criterion': 'entropy...         0.500546
# 20  {'randomforestclassifier__criterion': 'gini', ...         0.500192
# 19  {'randomforestclassifier__criterion': 'gini', ...         0.499314
# 6   {'randomforestclassifier__criterion': 'entropy...         0.497400
# 18  {'randomforestclassifier__criterion': 'gini', ...         0.494193
# 16  {'randomforestclassifier__criterion': 'gini', ...         0.444926
# 17  {'randomforestclassifier__criterion': 'gini', ...         0.441808
# 15  {'randomforestclassifier__criterion': 'gini', ...         0.441131
# 4   {'randomforestclassifier__criterion': 'entropy...         0.439402
# 3   {'randomforestclassifier__criterion': 'entropy...         0.439093
# 5   {'randomforestclassifier__criterion': 'entropy...         0.437469
# 12  {'randomforestclassifier__criterion': 'gini', ...         0.364799
# 0   {'randomforestclassifier__criterion': 'entropy...         0.361719
# 1   {'randomforestclassifier__criterion': 'entropy...         0.356288
# 13  {'randomforestclassifier__criterion': 'gini', ...         0.351733
# 2   {'randomforestclassifier__criterion': 'entropy...         0.345180
# 14  {'randomforestclassifier__criterion': 'gini', ...         0.337053
#
#     std_test_score  rank_test_score  mean_train_score  std_train_score
# 11        0.001786                1          0.999907         0.000042
# 23        0.002364                2          0.999897         0.000027
# 10        0.002775                3          0.998840         0.000175
# 22        0.002499                4          0.998774         0.000141
# 9         0.001657                5          0.986164         0.000234
# 21        0.002704                6          0.986058         0.000366
# 7         0.003719                7          0.510395         0.002805
# 8         0.001920                8          0.510031         0.001668
# 20        0.001494                9          0.510646         0.002393
# 19        0.002744               10          0.508579         0.002553
# 6         0.002208               11          0.506489         0.002286
# 18        0.002430               12          0.503556         0.002719
# 16        0.003695               13          0.448949         0.002263
# 17        0.003225               14          0.445442         0.001186
# 15        0.006008               15          0.444733         0.005850
# 4         0.003840               16          0.442935         0.002889
# 3         0.003432               17          0.441965         0.004450
# 5         0.001886               18          0.440372         0.003033
# 12        0.005994               19          0.365719         0.004698
# 0         0.002855               20          0.362459         0.003060
# 1         0.003062               21          0.357316         0.003972
# 13        0.004701               22          0.353131         0.003477
# 2         0.003871               23          0.345954         0.004123
# 14        0.002820               24          0.338195         0.004229

# %% [markdown]
# ### XGBoost

# %%
xgb_class = XGBClassifier(random_state=seed)
xgb_class_pipeline = make_pipeline(preprocessing, xgb_class)

param_grid = {
    'xgbclassifier__n_estimators': [10, 25, 50, 100],
    'xgbclassifier__max_depth': [3, 5, 7, 10, None],
    'xgbclassifier__learning_rate': [0.001, 0.005, 0.01, 0.05, 0.1, 0.2]
}

xgb_class_gs = optimize_params(xgb_class_pipeline, X_train, y_train, cv, scoring='f1_weighted', **param_grid)
# Out:
# Fitting 8 folds for each of 120 candidates, totalling 960 fits
# Time: 860.55 seg.
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 115      21.124042      0.302633         1.561242        0.059328
# 95       24.412941      0.293710         1.685831        0.070886
# 114      12.925971      0.162241         0.897412        0.047517
# 94       15.209643      0.172570         1.013881        0.038459
# 75       29.610080      0.277972         1.838876        0.147562
# ..             ...           ...              ...             ...
# 41        2.447839      0.100219         0.114016        0.008543
# 1         2.223206      0.031152         0.101435        0.009668
# 2         3.881504      0.052472         0.141498        0.013096
# 20        1.412193      0.029793         0.096262        0.014096
# 0         1.389159      0.019361         0.073339        0.007607
#
#     param_xgbclassifier__learning_rate param_xgbclassifier__max_depth  \
# 115                                0.2                             10
# 95                                 0.1                             10
# 114                                0.2                             10
# 94                                 0.1                             10
# 75                                0.05                             10
# ..                                 ...                            ...
# 41                                0.01                              3
# 1                                0.001                              3
# 2                                0.001                              3
# 20                               0.005                              3
# 0                                0.001                              3
#
#     param_xgbclassifier__n_estimators  \
# 115                               100
# 95                                100
# 114                                50
# 94                                 50
# 75                                100
# ..                                ...
# 41                                 25
# 1                                  25
# 2                                  50
# 20                                 10
# 0                                  10
#
#                                                 params  mean_test_score  \
# 115  {'xgbclassifier__learning_rate': 0.2, 'xgbclas...         0.627195
# 95   {'xgbclassifier__learning_rate': 0.1, 'xgbclas...         0.618593
# 114  {'xgbclassifier__learning_rate': 0.2, 'xgbclas...         0.617582
# 94   {'xgbclassifier__learning_rate': 0.1, 'xgbclas...         0.608337
# 75   {'xgbclassifier__learning_rate': 0.05, 'xgbcla...         0.608276
# ..                                                 ...              ...
# 41   {'xgbclassifier__learning_rate': 0.01, 'xgbcla...         0.422515
# 1    {'xgbclassifier__learning_rate': 0.001, 'xgbcl...         0.421914
# 2    {'xgbclassifier__learning_rate': 0.001, 'xgbcl...         0.421907
# 20   {'xgbclassifier__learning_rate': 0.005, 'xgbcl...         0.421899
# 0    {'xgbclassifier__learning_rate': 0.001, 'xgbcl...         0.421469
#
#      std_test_score  rank_test_score  mean_train_score  std_train_score
# 115        0.003514                1          0.868331         0.003146
# 95         0.002975                2          0.793995         0.002288
# 114        0.002737                3          0.797319         0.002549
# 94         0.002692                4          0.742797         0.002302
# 75         0.003364                5          0.743276         0.001778
# ..              ...              ...               ...              ...
# 41         0.006108              116          0.424656         0.003539
# 1          0.005311              117          0.423883         0.005458
# 2          0.005528              118          0.423886         0.005106
# 20         0.005463              119          0.423806         0.005166
# 0          0.005192              120          0.423390         0.006087
#
# [120 rows x 13 columns]

# %% [markdown]
# ### SGD

# %%
sgd_class = SGDClassifier(random_state=seed)
sgd_class_pipeline = make_pipeline(preprocessing, sgd_class)

param_grid = {
    'sgdclassifier__alpha': [0.0001, 0.001, 0.01, 0.1, 0.2, 0.5, 0.8],
    'sgdclassifier__max_iter': [50, 100, 500, 1000],
    'sgdclassifier__loss': ['log_loss', 'hinge', 'modified_huber']
}

sgd_class_gs = optimize_params(sgd_class_pipeline, X_train, y_train, cv, scoring='f1_weighted', **param_grid)
# Out:
# Fitting 8 folds for each of 180 candidates, totalling 1440 fits
# Time: 1377.26 seg.
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 112       2.515418      0.120805         0.059986        0.006223
# 111       2.511172      0.110801         0.059513        0.009936
# 110       2.498599      0.094907         0.057342        0.008019
# 109       2.528776      0.106622         0.054987        0.007011
# 108       2.590369      0.143261         0.057712        0.011486
# ..             ...           ...              ...             ...
# 166       1.198717      0.040953         0.062393        0.010062
# 167       1.210795      0.057262         0.064693        0.010072
# 163       1.205162      0.038457         0.053555        0.005227
# 162       1.208990      0.040598         0.063363        0.011684
# 164       1.201709      0.060186         0.062103        0.013071
#
#     param_sgdclassifier__alpha param_sgdclassifier__loss  \
# 112                     0.0001                  log_loss
# 111                     0.0001                  log_loss
# 110                     0.0001                  log_loss
# 109                     0.0001                  log_loss
# 108                     0.0001                  log_loss
# ..                         ...                       ...
# 166                        0.1                  log_loss
# 167                        0.1                  log_loss
# 163                        0.1                  log_loss
# 162                        0.1                  log_loss
# 164                        0.1                  log_loss
#
#     param_sgdclassifier__max_iter  \
# 112                          1000
# 111                           500
# 110                           300
# 109                           100
# 108                            50
# ..                            ...
# 166                          1000
# 167                          2000
# 163                           100
# 162                            50
# 164                           300
#
#                                                 params  mean_test_score  \
# 112  {'sgdclassifier__alpha': 0.0001, 'sgdclassifie...         0.409246
# 111  {'sgdclassifier__alpha': 0.0001, 'sgdclassifie...         0.409246
# 110  {'sgdclassifier__alpha': 0.0001, 'sgdclassifie...         0.409246
# 109  {'sgdclassifier__alpha': 0.0001, 'sgdclassifie...         0.409246
# 108  {'sgdclassifier__alpha': 0.0001, 'sgdclassifie...         0.409246
# ..                                                 ...              ...
# 166  {'sgdclassifier__alpha': 0.1, 'sgdclassifier__...         0.319164
# 167  {'sgdclassifier__alpha': 0.1, 'sgdclassifier__...         0.319164
# 163  {'sgdclassifier__alpha': 0.1, 'sgdclassifier__...         0.319164
# 162  {'sgdclassifier__alpha': 0.1, 'sgdclassifier__...         0.319164
# 164  {'sgdclassifier__alpha': 0.1, 'sgdclassifier__...         0.319164
#
#      std_test_score  rank_test_score  mean_train_score  std_train_score
# 112        0.004959                1          0.409885         0.004468
# 111        0.004959                1          0.409885         0.004468
# 110        0.004959                1          0.409885         0.004468
# 109        0.004959                1          0.409885         0.004468
# 108        0.004959                1          0.409885         0.004468
# ..              ...              ...               ...              ...
# 166        0.001996              175          0.319228         0.001576
# 167        0.001996              175          0.319228         0.001576
# 163        0.001996              175          0.319228         0.001576
# 162        0.001996              175          0.319228         0.001576
# 164        0.001996              175          0.319228         0.001576
#
# [180 rows x 13 columns]

# %% [markdown]
# ## Evaluación

# %%
class_dict = {
    'Regresion logistica': logistic_reg_gs,
    'KNeighbors' : k_neighbors_class_gs,
    'Arbol de decision': decision_tree_class_gs,
    'Random Forest': random_forest_class_gs,
    'XGBoost': xgb_class_gs,
    'SGD': sgd_class_gs
}


df_results_class = pd.DataFrame({
    'Modelo': class_dict.keys(),
    'Mejor puntuacion': [gs.best_score_ for gs in class_dict.values()]
})
df_results_class = df_results_class.sort_values(by='Mejor puntuacion', ascending=False)
df_results_class
# Out:
#                 Modelo  Mejor puntuacion
# 3        Random Forest          0.647980
# 4              XGBoost          0.627195
# 2    Arbol de decision          0.581348
# 1           KNeighbors          0.526210
# 0  Regresion logistica          0.518241
# 5                  SGD          0.409246

# %%
model = random_forest_class_gs.best_estimator_
model_path = os.path.join('models', 'experiment_1', 'model_class.joblib')
dump(model, model_path)
# Out:
# ['models\\model_1_class.joblib']

# %%
model_path = os.path.join('models', 'experiment_1', 'model_class.joblib')
model = load(model_path)
pred = model.predict(X_test)

print(f"""Métricas predicción del test
F1:        {f1_score(y_test, pred, average='weighted')}
Recall:    {recall_score(y_test, pred, average='weighted')}
Precision: {precision_score(y_test, pred, average='weighted')}
Accuracy:  {accuracy_score(y_test, pred)}""")
# Out:
# Métricas predicción del test
# F1:        0.660617605233689
# Recall:    0.6600650010156409
# Precision: 0.6633829307943221
# Accuracy:  0.6600650010156409
